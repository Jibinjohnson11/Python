# %% [markdown]
# ## Hand Cricket

# %%
import random
name = input("Enter Ur name")
print('__________________',name,"'s batting__________________")
def player1_choice():
    return random.choice(range(1,7))
r=[1,2,3,4,5,6]
def player2_choice():
    while True:
        choice = int(input("Enter your choice (1-6): "))
        if choice in r:
            return choice
        else:
            pass

def play_hand_cricket():
    
    player2_runs = 0    
    while True:
        player1 = player1_choice()
        player2 = player2_choice()

        print(f"Player 1 (Computer) chose: {player1}")
        print(f"{name} chose: {player2}")

        if player1 == player2:
            print('_________________________',name," is out!_________________________")
            print(f"{name}'s score: {player2_runs}")
            print('__________________________________________________________________')
            print(' ')
            print(' ')
            print(' ')
            print("_______________computer's batting_______________")

            break
        else:
            player2_runs += player2
            print(f"{name}'s score: {player2_runs}")
            
            


def player1_batting():
    global cmp
    cmp= random.choice
    return cmp
def player2_bowling():
    while True:
        choice = int(input("Enter your choice (1-6): "))
        if choice in r:
            return choice
        else:
            pass
def seccond_batting():
    player1_runs = 0
    
    while True:
        player1 = cmp
        player2 = player2_bowling

        print(f"Player 1 (Computer) chose: {player1}")
        print(f"{name} chose: {player2}")
        if player1==player2:
            print("_________________________computer is out!_________________________")
            print(f"computer's score: {player1_runs}")
            print('__________________________________________________________________')
            print(' ')
            print(' ')
            print(' ')
        
        elif player1<player2:
            print('____________________game over____________________')
            print('____________________computer win___________________')
        elif player1>player2:
            print('____________________game over____________________') 
            print('____________________',name,'win____________________')
        else:
            player1_runs+=player1
            print("computer's runs:",player1_runs)
            
            
player1_choice()
player2_choice()
play_hand_cricket()
player2_bowling()
player1_batting()
seccond_batting()
