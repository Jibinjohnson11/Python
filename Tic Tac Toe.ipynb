# %%
print('TIC TAC TOE')


player1=input('enter a player name:')
player2=input('enter a player name:')

import random
x=[player1,player2]
k=random.choice(x)

xo={player1:'x',player2:'o'}

b={7:' ',8:' ',9:' ',
   4:' ',5:' ',6:' ',
   1:' ',2:' ',3:' '}

def board(b):
    print(f' {b[7]} | {b[8] } | {b[9]} ')
    print('------------')
    print(f' {b[4]} | {b[5] } | {b[6]} ')
    print('------------')
    print(f' {b[1]} | {b[2] } | {b[3]} ')
def num():
    global s
    while True:
        s=input(' enter a number 1 to 9:')
        if s in '123456789':
            s=int(s)
            xochange()
            board(b)
            print(' ')
            print(' ')
            winner(b)
            if game==False:
                break
            else:
                pass
            playerchange()
            

            if b[s]=='x'or b[s]=='o':
                pass
            else:
                break

        else:
            print('enter a valid number')
            pass
    xochange()
    board(b)
def xochange():
    if k==player1:
        b[s]=xo[player1]
    else:
        b[s]=xo[player2]
def playerchange():
    global k
    if k==player1:
        k=player2
    else:
        k=player1

def winner(b):
    global game
    if (b[7]=='x' and b[8]=='x' and b[9]=='x') or( b[7]=='o' and b[8]=='o' and b[9]=='o'):
        print(k,'win')
        game=False
    elif (b[4]=='x' and b[5]=='x' and b[6]=='x') or (b[4]=='o' and b[5]=='o' and b[6]=='o'):
        print(k,'win')
        game=False
    elif ( b[1]=='x' and b[2]=='x' and b[3]=='x') or (b[1]=='o' and b[2]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[7]=='x' and b[4]=='x' and b[1]=='x') or (b[7]=='o' and b[4]=='o' and b[1]=='o'):
        print(k,'win')
        game=False
    elif (b[8]=='x' and b[5]=='x' and b[2]=='x') or (b[8]=='o' and b[5]=='o' and b[2]=='o'):
        print(k,'win')
        game=False
    elif (b[9]=='x' and b[6]=='x' and b[3]=='x') or (b[9]=='o' and b[6]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[7]=='x' and b[5]=='x' and b[3]=='x')or (b[7]=='o' and b[5]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[9]=='x' and b[5]=='x' and b[1]=='x') or (b[9]=='o' and b[5]=='o' and b[1]=='o'):
        print(k,'win')
        game=False
    elif b[1]!=' ' and b[2]!=' ' and b[3]!=' ' and b[4]!=' ' and b[5]!=' ' and b[6]!=' ' and b[7]!=' ' and b[8]!=' ' and b[9]!=' ':
        print('draw')
        game=False
    else:
        game=True
        return
    
    

    

















num()
# Out:
# TIC TAC TOE
# enter a player name:ashmitha
# enter a player name:jibin
#  enter a number 1 to 9:1
#    |   |
# ------------
#    |   |
# ------------
#  o |   |
#
#
#  enter a number 1 to 9:4
#    |   |
# ------------
#  x |   |
# ------------
#  o |   |
#
#
#  enter a number 1 to 9:5
#    |   |
# ------------
#  x | o |
# ------------
#  o |   |
#
#
#  enter a number 1 to 9:9
#    |   | x
# ------------
#  x | o |
# ------------
#  o |   |
#
#
#  enter a number 1 to 9:3
#    |   | x
# ------------
#  x | o |
# ------------
#  o |   | o
#
#
#  enter a number 1 to 9:2
#    |   | x
# ------------
#  x | o |
# ------------
#  o | x | o
#
#
#  enter a number 1 to 9:7
#  o |   | x
# ------------
#  x | o |
# ------------
#  o | x | o
#
#
# jibin win
#  o |   | x
# ------------
#  x | o |
# ------------
#  o | x | o

# %% [markdown]
# ## xo.keys()

# %%
print('TIC TAC TOE')


player1=input('enter a player name:')
player2=input('enter a player name:')

import random
x=[player1,player2]
k=random.choice(x)

xo={player1:'x',player2:'o'}

b={7:' ',8:' ',9:' ',
   4:' ',5:' ',6:' ',
   1:' ',2:' ',3:' '}

def board(b):
    print(f' {b[7]} | {b[8] } | {b[9]} ')
    print('------------')
    print(f' {b[4]} | {b[5] } | {b[6]} ')
    print('------------')
    print(f' {b[1]} | {b[2] } | {b[3]} ')
def num():
    global s
    while True:
        s=input(' enter a number 1 to 9:')
        if s in '123456789':
            s=int(s)
            xochange()
            board(b)
            print(' ')
            print(' ')
            winner(b)
            if game==False:
                break
            else:
                pass
            playerchange()
            

            if b[s]=='x'or b[s]=='o':
                pass
            else:
                break

        else:
            print('enter a valid number')
            pass
    xochange()
    board(b)
def xochange():
    if k==player1:
        b[s]=xo[player1]
    else:
        b[s]=xo[player2]
def playerchange():
    global k
    if k==player1:
        k=player2
    else:
        k=player1

def winner(b):
    global game
    if (b[7]=='x' and b[8]=='x' and b[9]=='x') or( b[7]=='o' and b[8]=='o' and b[9]=='o'):
        print(k,'win')
        game=False
    elif (b[4]=='x' and b[5]=='x' and b[6]=='x') or (b[4]=='o' and b[5]=='o' and b[6]=='o'):
        print(k,'win')
        game=False
    elif ( b[1]=='x' and b[2]=='x' and b[3]=='x') or (b[1]=='o' and b[2]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[7]=='x' and b[4]=='x' and b[1]=='x') or (b[7]=='o' and b[4]=='o' and b[1]=='o'):
        print(k,'win')
        game=False
    elif (b[8]=='x' and b[5]=='x' and b[2]=='x') or (b[8]=='o' and b[5]=='o' and b[2]=='o'):
        print(k,'win')
        game=False
    elif (b[9]=='x' and b[6]=='x' and b[3]=='x') or (b[9]=='o' and b[6]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[7]=='x' and b[5]=='x' and b[3]=='x')or (b[7]=='o' and b[5]=='o' and b[3]=='o'):
        print(k,'win')
        game=False
    elif (b[9]=='x' and b[5]=='x' and b[1]=='x') or (b[9]=='o' and b[5]=='o' and b[1]=='o'):
        print(k,'win')
        game=False
    elif b[1]!=' ' and b[2]!=' ' and b[3]!=' ' and b[4]!=' ' and b[5]!=' ' and b[6]!=' ' and b[7]!=' ' and b[8]!=' ' and b[9]!=' ':
        print('drow')
        game=False
    else:
        game=True
        return


num()
# Out:
# TIC TAC TOE
